# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# scipy.statsの中にt分布があります。
from scipy.stats import t

import numpy as np

# x軸の数字を用意します。
x = np.linspace(-5,5,100)

# 自由度3のt分布
rv = t(3)

# 確率密度関数（PDF）を書きます。
plt.plot(x, rv.pdf(x))
